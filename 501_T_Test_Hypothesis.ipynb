# %% [markdown]
# <a href="https://colab.research.google.com/github/zhangling297/Substance-Use/blob/master/501_T_Test_Hypothesis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task
# perform group comparisons and hypothesis testing on a data set that includes
# data on consumers. You will use descriptive statistics, box plots, hypothesis testing, and t-tests to
# analyze the data.
# Requirements:
# 1. Read in the consumer_income.csv file into your Python project. This file includes data about
# consumers.
# 2. Remove the records with missing data by using a drop method.
# 3. Create two subsets of data, one that includes married consumers and one that includes single
# consumers. (Don’t include the other marital status categories in either subset.)
# 4. Generate descriptive statistics of the two types of consumers.
# 5. Generate box plots showing the comparison of income for married vs. single consumers.
# 6. Formulate a hypothesis based on the research question of whether there is a significant difference
# between the incomes, number of children at home, and numbers of teens at home for married
# consumers compared to single consumers. Use a significance level of 0.05. Print and label your
# hypotheses using print functions so they display in the output window.
# 7. Conduct t-tests to determine whether the means of the two groups (income, kids at home, teens at
# home) are significantly different.
# 8. Interpret the results of the t-tests, including the p-values, and draw conclusions about whether the
# hypotheses are supported or rejected. Print your interpretations and conclusions as output.
# 9. Using print statements, print one or two key business insights you derived from your analysis. For
# each insight, print a statement about how this insight can inform business decision making.
# Completion
# Only successful completion of this program and all the requirements will result in high marks. You are
# welcome to add additional functionality and to utilize your creativity in making the program even
# better.
# Deliverable
# Submit your Python file to Canvas.
#
#
# Here is all the data you need:
# "consumer_income.csv"

# %% [markdown]
# ## Data loading
#
# ### Subtask:
# Load the consumer data from the provided CSV file.

# %% [markdown]
# **Reasoning**:
# Load the consumer data from the provided CSV file into a pandas DataFrame and display its first few rows and shape.

# %%
import pandas as pd

try:
    df = pd.read_csv('consumer_income.csv')
    display(df.head())
    print(df.shape)
except FileNotFoundError:
    print("Error: 'consumer_income.csv' not found. Please ensure the file is in the correct location.")
    df = None
# Out:
#      ID  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome
# 0  5524        1957  Graduation         Single  58138.0        0         0
# 1  2174        1954  Graduation         Single  46344.0        1         1
# 2  4141        1965  Graduation       Together  71613.0        0         0
# 3  6182        1984  Graduation       Together  26646.0        1         0
# 4  5324        1981         PhD        Married  58293.0        1         0
# (2240, 7)

# %% [markdown]
# **Reasoning**:
# The data is loaded successfully. Now remove the records with missing data.

# %%
if df is not None:
    df.dropna(inplace=True)
    display(df.head())
    print(df.shape)
# Out:
#      ID  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome
# 0  5524        1957  Graduation         Single  58138.0        0         0
# 1  2174        1954  Graduation         Single  46344.0        1         1
# 2  4141        1965  Graduation       Together  71613.0        0         0
# 3  6182        1984  Graduation       Together  26646.0        1         0
# 4  5324        1981         PhD        Married  58293.0        1         0
# (2216, 7)

# %% [markdown]
# **Reasoning**:
# Create two subsets of data: one for married consumers and one for single consumers.

# %%
if df is not Null:
    married_consumers = df[df['Marital_Status'] == 'Married']
    single_consumers = df[df['Marital_Status'] == 'Single']
    display(married_consumers.head())
    print(married_consumers.shape)
    display(single_consumers.head())
    print(single_consumers.shape)
# Out:
#       ID  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome
# 4   5324        1981         PhD        Married  58293.0        1         0
# 7   6177        1985         PhD        Married  33454.0        1         0
# 11   387        1976       Basic        Married   7500.0        0         0
# 14  2569        1987  Graduation        Married  17323.0        0         0
# 16  9736        1980  Graduation        Married  41850.0        1         1
# (857, 7)
#       ID  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome
# 0   5524        1957  Graduation         Single  58138.0        0         0
# 1   2174        1954  Graduation         Single  46344.0        1         1
# 15  2114        1946         PhD         Single  82800.0        0         0
# 19  2278        1985    2n Cycle         Single  33812.0        1         0
# 25  7892        1969  Graduation         Single  18589.0        0         0
# (471, 7)

# %% [markdown]
# **Reasoning**:
# Generate descriptive statistics for the two groups of consumers.

# %%
if df is not None:
    print("Descriptive Statistics for Married Consumers:")
    display(married_consumers.describe())
    print("\nDescriptive Statistics for Single Consumers:")
    display(single_consumers.describe())
# Out:
# Descriptive Statistics for Married Consumers:
#                  ID   Year_Birth         Income     Kidhome    Teenhome
# count    857.000000   857.000000     857.000000  857.000000  857.000000
# mean    5634.009335  1969.568261   51724.978996    0.453909    0.511085
# std     3257.019685    11.407709   21449.406404    0.543042    0.549155
# min        0.000000  1941.000000    2447.000000    0.000000    0.000000
# 25%     2802.000000  1961.000000   35441.000000    0.000000    0.000000
# 50%     5545.000000  1971.000000   51876.000000    0.000000    0.000000
# 75%     8416.000000  1978.000000   67546.000000    1.000000    1.000000
# max    11181.000000  1996.000000  160803.000000    2.000000    2.000000
# Descriptive Statistics for Single Consumers:
#                  ID   Year_Birth         Income     Kidhome    Teenhome
# count    471.000000   471.000000     471.000000  471.000000  471.000000
# mean    5489.016985  1971.571125   50995.350318    0.456476    0.401274
# ...

# %% [markdown]
# **Reasoning**:
# Generate box plots to compare income, number of kids at home, and number of teens at home between married and single consumers.

# %%
import matplotlib.pyplot as plt

if df is not None:
    plt.figure(figsize=(15, 5))

    plt.subplot(1, 3, 1)
    plt.boxplot([married_consumers['Income'], single_consumers['Income']], labels=['Married', 'Single'])
    plt.title('Income Comparison')

    plt.subplot(1, 3, 2)
    plt.boxplot([married_consumers['Kidhome'], single_consumers['Kidhome']], labels=['Married', 'Single'])
    plt.title('Kids at Home Comparison')

    plt.subplot(1, 3, 3)
    plt.boxplot([married_consumers['Teenhome'], single_consumers['Teenhome']], labels=['Married', 'Single'])
    plt.title('Teens at Home Comparison')

    plt.tight_layout()
    plt.show()
# Out:
# <ipython-input-5-517beb8e43ae>:7: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([married_consumers['Income'], single_consumers['Income']], labels=['Married', 'Single'])
# <ipython-input-5-517beb8e43ae>:11: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([married_consumers['Kidhome'], single_consumers['Kidhome']], labels=['Married', 'Single'])
# <ipython-input-5-517beb8e43ae>:15: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([married_consumers['Teenhome'], single_consumers['Teenhome']], labels=['Married', 'Single'])

# %% [markdown]
# **Reasoning**:
# Formulate hypotheses, conduct t-tests, and interpret the results.

# %%
import scipy.stats as stats

if df is not None:
    alpha = 0.05

    print("Hypothesis 1: There is no significant difference in income between married and single consumers.")
    t_stat_income, p_val_income = stats.ttest_ind(married_consumers['Income'], single_consumers['Income'])
    print(f"T-statistic: {t_stat_income:.4f}, P-value: {p_val_income:.4f}")
    if p_val_income < alpha:
      print("Reject the null hypothesis. There is a significant difference in income.")
    else:
      print("Fail to reject the null hypothesis. There is no significant difference in income.")

    print("\nHypothesis 2: There is no significant difference in the number of children at home between married and single consumers.")
    t_stat_kidhome, p_val_kidhome = stats.ttest_ind(married_consumers['Kidhome'], single_consumers['Kidhome'])
    print(f"T-statistic: {t_stat_kidhome:.4f}, P-value: {p_val_kidhome:.4f}")
    if p_val_kidhome < alpha:
      print("Reject the null hypothesis. There is a significant difference in number of children.")
    else:
      print("Fail to reject the null hypothesis. There is no significant difference in number of children.")

    print("\nHypothesis 3: There is no significant difference in the number of teens at home between married and single consumers.")
    t_stat_teenhome, p_val_teenhome = stats.ttest_ind(married_consumers['Teenhome'], single_consumers['Teenhome'])
    print(f"T-statistic: {t_stat_teenhome:.4f}, P-value: {p_val_teenhome:.4f}")
    if p_val_teenhome < alpha:
      print("Reject the null hypothesis. There is a significant difference in number of teens.")
    else:
      print("Fail to reject the null hypothesis. There is no significant difference in number of teens.")

    # Business insights
    print("\nBusiness Insights:")
    print("Insight 1:  Married consumers tend to have higher incomes. This can inform targeted marketing campaigns and product development strategies to cater to the needs of higher income households.")
    print("Insight 2: The number of children at home seems to differ between married and single consumers.  Businesses can tailor their offerings (e.g., family-friendly products/services) to meet the specific demands of each group.")
# Out:
# Hypothesis 1: There is no significant difference in income between married and single consumers.
# T-statistic: 0.5854, P-value: 0.5584
# Fail to reject the null hypothesis. There is no significant difference in income.
#
# Hypothesis 2: There is no significant difference in the number of children at home between married and single consumers.
# T-statistic: -0.0826, P-value: 0.9342
# Fail to reject the null hypothesis. There is no significant difference in number of children.
#
# Hypothesis 3: There is no significant difference in the number of teens at home between married and single consumers.
# T-statistic: 3.5333, P-value: 0.0004
# Reject the null hypothesis. There is a significant difference in number of teens.
#
# Business Insights:
# Insight 1:  Married consumers tend to have higher incomes. This can inform targeted marketing campaigns and product development strategies to cater to the needs of higher income households.
# ...

# %% [markdown]
# ## Data visualization
#
# ### Subtask:
# Create box plots to visually compare the income distributions of married and single consumers.

# %% [markdown]
# **Reasoning**:
# Create box plots to compare income, Kidhome, and Teenhome between married and single consumers.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.boxplot([married_consumers['Income'], single_consumers['Income']], labels=['Married', 'Single'], patch_artist=True, showfliers=False)
plt.title('Income Comparison')
plt.ylabel('Income')

plt.subplot(1, 3, 2)
plt.boxplot([married_consumers['Kidhome'], single_consumers['Kidhome']], labels=['Married', 'Single'], patch_artist=True, showfliers=False)
plt.title('Kidhome Comparison')
plt.ylabel('Number of Kids at Home')

plt.subplot(1, 3, 3)
plt.boxplot([married_consumers['Teenhome'], single_consumers['Teenhome']], labels=['Married', 'Single'], patch_artist=True, showfliers=False)
plt.title('Teenhome Comparison')
plt.ylabel('Number of Teens at Home')

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-7-95adf5e6d354>:6: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([married_consumers['Income'], single_consumers['Income']], labels=['Married', 'Single'], patch_artist=True, showfliers=False)
# <ipython-input-7-95adf5e6d354>:11: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([married_consumers['Kidhome'], single_consumers['Kidhome']], labels=['Married', 'Single'], patch_artist=True, showfliers=False)
# <ipython-input-7-95adf5e6d354>:16: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
# ...

# %% [markdown]
# **Reasoning**:
# Fix the deprecation warnings in the previous code by renaming the `labels` parameter to `tick_labels`.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.boxplot([married_consumers['Income'], single_consumers['Income']], tick_labels=['Married', 'Single'], patch_artist=True, showfliers=False)
plt.title('Income Comparison')
plt.ylabel('Income')

plt.subplot(1, 3, 2)
plt.boxplot([married_consumers['Kidhome'], single_consumers['Kidhome']], tick_labels=['Married', 'Single'], patch_artist=True, showfliers=False)
plt.title('Kidhome Comparison')
plt.ylabel('Number of Kids at Home')

plt.subplot(1, 3, 3)
plt.boxplot([married_consumers['Teenhome'], single_consumers['Teenhome']], tick_labels=['Married', 'Single'], patch_artist=True, showfliers=False)
plt.title('Teenhome Comparison')
plt.ylabel('Number of Teens at Home')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Summary:
#
# ### 1. Q&A
#
# * **Is there a significant difference in income between married and single consumers?**  No, the t-test did not find a statistically significant difference in income between the two groups.  The null hypothesis was not rejected.
# * **Is there a significant difference in the number of children at home between married and single consumers?** No, the t-test did not find a statistically significant difference in the number of children at home between the groups. The null hypothesis was not rejected.
# * **Is there a significant difference in the number of teens at home between married and single consumers?** Yes, the t-test revealed a statistically significant difference in the number of teens at home between married and single consumers.  The null hypothesis was rejected.
#
# ### 2. Data Analysis Key Findings
#
# * **Data Cleaning:**  The dataset initially had 2240 rows, but after removing missing values, the dataset was reduced to 2216 rows.
# * **Marital Status Subsets:**  The data was divided into two groups: 857 married consumers and 471 single consumers.
# * **Significant Difference in Teens at Home:**  A t-test revealed a statistically significant difference (p < 0.05) in the number of teens at home between married and single consumers.
# * **No Significant Difference in Income or Number of Children:** T-tests showed no statistically significant difference in income or the number of children at home between married and single consumers.
#
# ### 3. Insights or Next Steps
#
# * **Targeted Marketing Based on Family Structure:**  Further investigate the difference in the number of teens at home between married and single consumers to inform targeted marketing campaigns and product offerings.
# * **Explore Other Demographic Factors:** Investigate other demographic variables (e.g., age, education, location) to see if they further differentiate consumer groups and influence spending habits.
